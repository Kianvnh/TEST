# %%
import pandas as pd
import statsmodels.formula.api as sm

# %%
df = pd.read_csv('dataset_Facebook.csv')
df.head()
# Out:
#    Page_total_likes    Type  Post_Month  Post_Weekday  Post_Hour   Payment  \
# 0            139441   Photo          12             4          3  Not_Paid
# 1            139441  Status          12             3         10  Not_Paid
# 2            139441   Photo          12             3          3  Not_Paid
# 3            139441   Photo          12             2         10      Paid
# 4            139441   Photo          12             2          3  Not_Paid
#
#    Lifetime_Post_Total_Reach  Lifetime_Post_Total_Impressions  \
# 0                       2752                             5091
# 1                      10460                            19057
# 2                       2413                             4373
# 3                      50128                            87991
# 4                       7244                            13594
#
#    Lifetime_Engaged_Users  Lifetime_Post_Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# 3                    2211                      790
# 4                     671                      410
#
#    Lifetime_Post_Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
#
#    Lifetime_Post_Impressions_by_people_who_have_liked_your_Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
# 4                                               6228
#
#    Lifetime_Post_reach_by_people_who_like_your_Page  \
# 0                                              1640
# 1                                              6112
# 2                                              1503
# 3                                             32048
# 4                                              3200
#
#    Lifetime_People_who_have_liked_your_Page_and_engaged_with_your_post  \
# 0                                                119
# 1                                               1108
# 2                                                132
# 3                                               1386
# 4                                                396
#
#    comment  like  share  Total_Interactions
# 0        4    79     17                 100
# 1        5   130     29                 164
# 2        0    66     14                  80
# 3       58  1572    147                1777
# 4       19   325     49                 393

# %%
df_facebook_dummies = pd.get_dummies(df[['Type', 'Payment']])
df = pd.concat([df, df_facebook_dummies], axis = 1)
print(df)
# Out:
#      Page_total_likes    Type  Post_Month  Post_Weekday  Post_Hour   Payment  \
# 0              139441   Photo          12             4          3  Not_Paid
# 1              139441  Status          12             3         10  Not_Paid
# 2              139441   Photo          12             3          3  Not_Paid
# 3              139441   Photo          12             2         10      Paid
# 4              139441   Photo          12             2          3  Not_Paid
# ..                ...     ...         ...           ...        ...       ...
# 490             85093   Photo           1             7         10  Not_Paid
# 491             85093   Photo           1             7          2  Not_Paid
# 492             81370   Photo         100             5          8  Not_Paid
# 493             81370   Photo         100             5          2  Not_Paid
# 494             81370   Photo         100             4         11  Not_Paid
#
#      Lifetime_Post_Total_Reach  Lifetime_Post_Total_Impressions  \
# 0                         2752                             5091
# 1                        10460                            19057
# 2                         2413                             4373
# 3                        50128                            87991
# 4                         7244                            13594
# ..                         ...                              ...
# 490                       5400                             9218
# 491                       4684                             7536
# 492                       3480                             6229
# 493                       3778                             7216
# 494                       4156                             7564
#
#      Lifetime_Engaged_Users  Lifetime_Post_Consumers  ...  Type_Status  \
# 0                       178                      109  ...        False
# 1                      1457                     1361  ...         True
# 2                       177                      113  ...        False
# 3                      2211                      790  ...        False
# 4                       671                      410  ...        False
# ..                      ...                      ...  ...          ...
# 490                     810                      756  ...        False
# 491                     733                      708  ...        False
# 492                     537                      508  ...        False
# 493                     625                      572  ...        False
# 494                     626                      574  ...        False
#
#      Type_Video  Payment_Not_Paid  Payment_Paid  Type_Link  Type_Photo  \
# 0         False              True         False      False        True
# 1         False              True         False      False       False
# 2         False              True         False      False        True
# 3         False             False          True      False        True
# 4         False              True         False      False        True
# ..          ...               ...           ...        ...         ...
# 490       False              True         False      False        True
# 491       False              True         False      False        True
# 492       False              True         False      False        True
# 493       False              True         False      False        True
# 494       False              True         False      False        True
#
#      Type_Status  Type_Video  Payment_Not_Paid  Payment_Paid
# 0          False       False              True         False
# 1           True       False              True         False
# 2          False       False              True         False
# 3          False       False             False          True
# 4          False       False              True         False
# ..           ...         ...               ...           ...
# 490        False       False              True         False
# 491        False       False              True         False
# 492        False       False              True         False
# 493        False       False              True         False
# 494        False       False              True         False
#
# [495 rows x 30 columns]

# %%
#Lifetime_Engaged_Users = df['Lifetime_Engaged_Users']
#Status = df['Status']
#Video = df['Video']
#Link = df['Link']
#Paid = df['Paid']
#Post_month = df['Post_month']
#Type = df['Type']

model1 = sm.ols('Lifetime_Engaged_Users~Type', data = df).fit() #idk man
print(model1.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Lifetime_Engaged_Users   R-squared:                       0.149
# Model:                                OLS   Adj. R-squared:                  0.144
# Method:                     Least Squares   F-statistic:                     28.69
# Date:                    Thu, 21 Mar 2024   Prob (F-statistic):           4.15e-17
# Time:                            13:33:35   Log-Likelihood:                -4075.1
# No. Observations:                     495   AIC:                             8158.
# Df Residuals:                         491   BIC:                             8175.
# Df Model:                               3
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        342.8182    194.835      1.760      0.079     -39.996     725.632
# Type[T.Photo]    482.5500    199.861      2.414      0.016      89.861     875.239
# Type[T.Status]  1697.4040    237.738      7.140      0.000    1230.294    2164.514
# Type[T.Video]   1364.1818    396.568      3.440      0.001     585.002    2143.362
# ==============================================================================
# Omnibus:                      555.330   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            45860.557
# Skew:                           5.064   Prob(JB):                         0.00
# Kurtosis:                      49.054   Cond. No.                         14.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# To check if data has missing values use: df.isnull().sum()
# If you want to completly remove these values: df.dropna()
# To create a dummy for missings: data_new = pd.get_dummies(data, dummy_na=True)

# %%
dfm = pd.read_csv('insurance_missings.csv')
dfm.head()
# Out:
#    age     sex    bmi  children smoker     region      charges
# 0   19  female  27.90         0    yes  southwest  16884.92400
# 1   31  female  25.74         0     no  southeast   3756.62160
# 2   60  female  25.84         0     no  northwest  28923.13692
# 3   62  female  26.29         0    yes  southeast  27808.72510
# 4   56  female  39.82         0     no  southeast  11090.71780

# %%
dfm.isnull().sum()
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
ds_missing_dummies = pd.get_dummies(dfm[['sex', 'smoker']])
dfm = pd.concat([dfm, ds_missing_dummies], axis = 1)

# %%
dfm.isnull().sum()
# Out:
# age             0
# sex             0
# bmi           197
# children        0
# smoker        106
# region          0
# charges         0
# sex_female      0
# sex_male        0
# smoker_no       0
# smoker_yes      0
# sex_female      0
# sex_male        0
# smoker_no       0
# smoker_yes      0
# sex_female      0
# sex_male        0
# smoker_no       0
# smoker_yes      0
# dtype: int64

# %%
dfm_new = pd.get_dummies(dfm, dummy_na=True)
imputed_data = IterativeImputer().fit_transform(dfm_new)

# %%
dfm_new.head()
# Out:
#    age    bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0   19  27.90         0  16884.92400        True     False      False
# 1   31  25.74         0   3756.62160        True     False       True
# 2   60  25.84         0  28923.13692        True     False       True
# 3   62  26.29         0  27808.72510        True     False      False
# 4   56  39.82         0  11090.71780        True     False       True
#
#    smoker_yes  sex_female  sex_male  ...  sex_male  sex_nan  smoker_no  \
# 0        True        True     False  ...     False    False      False
# 1       False        True     False  ...     False    False       True
# 2       False        True     False  ...     False    False       True
# 3        True        True     False  ...     False    False      False
# 4       False        True     False  ...     False    False       True
#
#    smoker_yes  smoker_nan  region_northeast  region_northwest  \
# 0        True       False             False             False
# 1       False       False             False             False
# 2       False       False             False              True
# 3        True       False             False             False
# 4       False       False             False             False
#
#    region_southeast  region_southwest  region_nan
# 0             False              True       False
# 1              True             False       False
# 2             False             False       False
# 3              True             False       False
# 4              True             False       False
#
# [5 rows x 27 columns]

# %%
ds_missing_dummies_new = pd.get_dummies(dfm_new[['sex', 'smoker']])
dfm_new = pd.concat([dfm, ds_missing_dummies_new], axis = 1)

# %%
imputed_data = pd.DataFrame(imputed_data, columns=dfm_new.columns)

# %%
model2 = sm.ols('charges~age + sex + bmi + children + smoker', data=dfm).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                     660.9
# Date:                Thu, 21 Mar 2024   Prob (F-statistic):          1.51e-320
# Time:                        14:27:12   Log-Likelihood:                -10655.
# No. Observations:                1051   AIC:                         2.132e+04
# Df Residuals:                    1045   BIC:                         2.135e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.232e+04   1087.524    -11.328      0.000   -1.45e+04   -1.02e+04
# sex[T.male]    -356.9742    384.609     -0.928      0.354   -1111.669     397.721
# smoker[T.yes]   2.46e+04    471.315     52.195      0.000    2.37e+04    2.55e+04
# age             268.4867     13.417     20.011      0.000     242.159     294.815
# bmi             321.2816     31.371     10.241      0.000     259.723     382.840
# children        487.6372    161.389      3.022      0.003     170.954     804.320
# ==============================================================================
# Omnibus:                      225.441   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              545.152
# Skew:                           1.143   Prob(JB):                    4.19e-119
# Kurtosis:                       5.687   Cond. No.                         295.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model2_new = sm.ols('charges~age + sex + bmi + children + smoker', data=dfm_new).fit()
print(model2_new.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/.python/current/lib/python3.10/site-packages/patsy/compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File ~/.python/current/lib/python3.10/site-packages/patsy/eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'smoker' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 model2_new = sm.ols('charges~age + sex + bmi + children + smoker', data=dfm_new)
#       2 print(model2_new)
#
# File ~/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:203, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     200 if missing == 'none':  # with patsy it's drop or raise. let's raise.
#     201     missing = 'raise'
# --> 203 tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     204                           missing=missing)
#     205 ((endog, exog), missing_idx, design_info) = tmp
#     206 max_endog = cls._formula_max_endog
#
# File ~/.python/current/lib/python3.10/site-packages/statsmodels/formula/formulatools.py:63, in handle_formula_data(Y, X, formula, depth, missing)
#      61 else:
#      62     if data_util._is_using_pandas(Y, None):
# ---> 63         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                            NA_action=na_action)
#      65     else:
#      66         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      67                            NA_action=na_action)
#
# File ~/.python/current/lib/python3.10/site-packages/patsy/highlevel.py:309, in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     299 """Construct two design matrices given a formula_like and data.
#     300
#     301 This function is identical to :func:`dmatrix`, except that it requires
#    (...)
#     306 See :func:`dmatrix` for details.
#     307 """
#     308 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309 (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                   NA_action, return_type)
#     311 if lhs.shape[1] == 0:
#     312     raise PatsyError("model is missing required outcome variables")
#
# File ~/.python/current/lib/python3.10/site-packages/patsy/highlevel.py:164, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162 def data_iter_maker():
#     163     return iter([data])
# --> 164 design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                   NA_action)
#     166 if design_infos is not None:
#     167     return build_design_matrices(design_infos, data,
#     168                                  NA_action=NA_action,
#     169                                  return_type=return_type)
#
# File ~/.python/current/lib/python3.10/site-packages/patsy/highlevel.py:66, in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      64 if isinstance(formula_like, ModelDesc):
#      65     assert isinstance(eval_env, EvalEnvironment)
# ---> 66     return design_matrix_builders([formula_like.lhs_termlist,
#      67                                    formula_like.rhs_termlist],
#      68                                   data_iter_maker,
#      69                                   eval_env,
#      70                                   NA_action)
#      71 else:
#      72     return None
#
# File ~/.python/current/lib/python3.10/site-packages/patsy/build.py:693, in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     689 factor_states = _factors_memorize(all_factors, data_iter_maker, eval_env)
#     690 # Now all the factors have working eval methods, so we can evaluate them
#     691 # on some data to find out what type of data they return.
#     692 (num_column_counts,
# --> 693  cat_levels_contrasts) = _examine_factor_types(all_factors,
#     694                                                factor_states,
#     695                                                data_iter_maker,
#     696                                                NA_action)
#     697 # Now we need the factor infos, which encapsulate the knowledge of
#     698 # how to turn any given factor into a chunk of data:
#     699 factor_infos = {}
#
# File ~/.python/current/lib/python3.10/site-packages/patsy/build.py:443, in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441 for data in data_iter_maker():
#     442     for factor in list(examine_needed):
# --> 443         value = factor.eval(factor_states[factor], data)
#     444         if factor in cat_sniffers or guess_categorical(value):
#     445             if factor not in cat_sniffers:
#
# File ~/.python/current/lib/python3.10/site-packages/patsy/eval.py:568, in EvalFactor.eval(self, memorize_state, data)
#     567 def eval(self, memorize_state, data):
# --> 568     return self._eval(memorize_state["eval_code"],
#     569                       memorize_state,
#     570                       data)
#
# File ~/.python/current/lib/python3.10/site-packages/patsy/eval.py:551, in EvalFactor._eval(self, code, memorize_state, data)
#     549 def _eval(self, code, memorize_state, data):
#     550     inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 551     return call_and_wrap_exc("Error evaluating factor",
#     552                              self,
#     553                              memorize_state["eval_env"].eval,
#     554                              code,
#     555                              inner_namespace=inner_namespace)
#
# File ~/.python/current/lib/python3.10/site-packages/patsy/compat.py:43, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      39     new_exc = PatsyError("%s: %s: %s"
#      40                          % (msg, e.__class__.__name__, e),
#      41                          origin)
#      42     # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43     exec("raise new_exc from e")
#      44 else:
#      45     # In python 2, we just let the original exception escape -- better
#      46     # than destroying the traceback. But if it's a PatsyError, we can
#      47     # at least set the origin properly.
#      48     if isinstance(e, PatsyError):
#
# File <string>:1
#
# PatsyError: Error evaluating factor: NameError: name 'smoker' is not defined
#     charges~age + sex + bmi + children + smoker
#                                          ^^^^^^
